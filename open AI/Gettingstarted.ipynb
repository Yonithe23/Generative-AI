# %% [markdown]
# #### Getting started With Langchain And Open AI
#
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI 
llm = ChatOpenAI( model="gpt-4o")

# %%
result = llm.invoke("write about generative AI")
result
# Out:
# AIMessage(content='Generative AI refers to a subset of artificial intelligence technologies that are designed to create new content. It leverages complex algorithms and models to generate data that resembles the training dataset it was fed, whether in the form of text, images, music, or other media. The most prominent deep learning architectures used in generative AI include Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and transformer models, such as the widely recognized GPT (Generative Pre-trained Transformer) series.\n\n**Generative Adversarial Networks (GANs)** consist of two neural networks: a generator and a discriminator. The generator creates new data instances, while the discriminator evaluates them. The two networks are trained simultaneously in a loop, with the generator improving its outputs to fool the discriminator, and the discriminator getting better at distinguishing real from fake data. This adversarial process leads to highly realistic outputs, making GANs a popular choice for image synthesis and other creative applications.\n\n**Variational Autoencoders (VAEs)** are another type of generative model that use encoder-decoder architecture. VAEs learn to encode input data into a latent space and then decode it back to the original data or generate new data. This model is particularly useful for tasks requiring smooth interpolation between data points, such as generating variations of an image.\n\n**Transformer Models,** including those like GPT, have revolutionized the field of natural language processing. They use attention mechanisms to weigh the importance of different words or tokens in input data, allowing them to generate coherent and contextually relevant text. These models are trained on vast amounts of data and fine-tuned for specific tasks, making them incredibly versatile for text-based applications, from chatbots and essays to code generation.\n\nGenerative AI has numerous applications across various industries:\n\n1. **Art and Design:** Artists and designers use generative AI to create new and unique pieces of work. AI can assist in generating novel patterns, music compositions, and even entire paintings, offering creative inspiration and new styles.\n\n2. **Content Creation:** In media and entertainment, generative AI automates the creation of blogs, articles, and scripts, or transforms story concepts into detailed narratives. \n\n3. **Gaming:** Game developers use generative AI to create immersive virtual worlds, with auto-generated landscapes, levels, and character designs, reducing the need for manual asset creation.\n\n4. **Healthcare:** In drug development, generative models can simulate molecular structures to predict how they interact, potentially accelerating the discovery of new medications.\n\n5. **Personalization:** Businesses use generative AI to create personalized content for users. This ranges from tailored marketing messages to individualized news feeds.\n\nDespite its wide-ranging applications, generative AI poses challenges and ethical considerations. The risk of creating deepfakes, content used for misinformation, and issues related to intellectual property rights are significant concerns. Moreover, ensuring diversity and preventing bias in AI-generated content is an ongoing challenge as the technology continues to evolve.\n\nGenerative AI is a powerful tool that drives innovation and creativity, though its development must be managed carefully to harness its benefits while mitigating potential risks. As the technology progresses, it promises to further blur the boundaries between human and machine-generated content, opening up new possibilities in science, technology, and the arts.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 659, 'prompt_tokens': 12, 'total_tokens': 671, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_token ...

# %%
print(result)
# Out:
# content='Generative AI refers to a subset of artificial intelligence technologies that are designed to create new content. It leverages complex algorithms and models to generate data that resembles the training dataset it was fed, whether in the form of text, images, music, or other media. The most prominent deep learning architectures used in generative AI include Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and transformer models, such as the widely recognized GPT (Generative Pre-trained Transformer) series.\n\n**Generative Adversarial Networks (GANs)** consist of two neural networks: a generator and a discriminator. The generator creates new data instances, while the discriminator evaluates them. The two networks are trained simultaneously in a loop, with the generator improving its outputs to fool the discriminator, and the discriminator getting better at distinguishing real from fake data. This adversarial process leads to highly realistic outputs, making GANs a popular choice for image synthesis and other creative applications.\n\n**Variational Autoencoders (VAEs)** are another type of generative model that use encoder-decoder architecture. VAEs learn to encode input data into a latent space and then decode it back to the original data or generate new data. This model is particularly useful for tasks requiring smooth interpolation between data points, such as generating variations of an image.\n\n**Transformer Models,** including those like GPT, have revolutionized the field of natural language processing. They use attention mechanisms to weigh the importance of different words or tokens in input data, allowing them to generate coherent and contextually relevant text. These models are trained on vast amounts of data and fine-tuned for specific tasks, making them incredibly versatile for text-based applications, from chatbots and essays to code generation.\n\nGenerative AI has numerous applications across various industries:\n\n1. **Art and Design:** Artists and designers use generative AI to create new and unique pieces of work. AI can assist in generating novel patterns, music compositions, and even entire paintings, offering creative inspiration and new styles.\n\n2. **Content Creation:** In media and entertainment, generative AI automates the creation of blogs, articles, and scripts, or transforms story concepts into detailed narratives. \n\n3. **Gaming:** Game developers use generative AI to create immersive virtual worlds, with auto-generated landscapes, levels, and character designs, reducing the need for manual asset creation.\n\n4. **Healthcare:** In drug development, generative models can simulate molecular structures to predict how they interact, potentially accelerating the discovery of new medications.\n\n5. **Personalization:** Businesses use generative AI to create personalized content for users. This ranges from tailored marketing messages to individualized news feeds.\n\nDespite its wide-ranging applications, generative AI poses challenges and ethical considerations. The risk of creating deepfakes, content used for misinformation, and issues related to intellectual property rights are significant concerns. Moreover, ensuring diversity and preventing bias in AI-generated content is an ongoing challenge as the technology continues to evolve.\n\nGenerative AI is a powerful tool that drives innovation and creativity, though its development must be managed carefully to harness its benefits while mitigating potential risks. As the technology progresses, it promises to further blur the boundaries between human and machine-generated content, opening up new possibilities in science, technology, and the arts.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 659, 'prompt_tokens': 12, 'total_tokens': 671, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'pro ...

# %%
type(result)
# Out:
# langchain_core.messages.ai.AIMessage

# %% [markdown]
# ### Chatprompt Template

# %%
from langchain_core.prompts import  ChatPromptTemplate
promt = ChatPromptTemplate.from_messages(
    [
       ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]
)

promt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = promt|llm
response = chain.invoke("what is generative AI")
response
# Out:
# AIMessage(content='Generative AI refers to a category of artificial intelligence models and algorithms designed to generate new content. This can include text, images, music, or other forms of data, often indistinguishable from what a human might produce. These models are typically based on machine learning techniques such as neural networks, including architectures like Generative Adversarial Networks (GANs) and transformer models, like those used in GPT (Generative Pre-trained Transformer).\n\nThe key aspect of generative AI is its ability to create or simulate new content after being trained on large datasets. It uses patterns and structures learned from the data to produce outputs that are creative and original. Applications of generative AI range from creating realistic images and deepfakes to composing music, developing chatbots with human-like conversations, and even assisting in drug discovery and design.\n\nOn the creative side, generative AI is used in areas like art, design, and entertainment, enabling the creation of new ideas and styles. In industry and research, it helps automate complex tasks and provides new approaches to problem-solving.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 212, 'prompt_tokens': 30, 'total_tokens': 242, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f9f4fb6dbf', 'finish_reason': 'stop', 'logprobs': None}, id='run-aeea70da-282d-4775-8b6d-67ea777f0e88-0', usage_metadata={'input_tokens': 30, 'output_tokens': 212, 'total_tokens': 242, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.output_parsers import  StrOutputParser
out_parser= StrOutputParser()
chain = promt|llm|out_parser

result = chain.invoke({"input" : "what is generative AI "})
print(result)
# Out:
# Generative AI refers to a category of artificial intelligence models and systems designed to generate new content based on the data they've been trained on. Unlike traditional AI systems, which focus on classifying or predicting based on existing data, generative AI creates new data that resembles the input data. This can include generating text, images, music, video, and more.
#
# Some popular examples of generative AI models include:
#
# 1. **Generative Adversarial Networks (GANs):** Used to generate images, videos, and other data types. They consist of two networks—a generator and a discriminator—that work together to produce increasingly realistic outputs.
#
# 2. **Variational Autoencoders (VAEs):** Used for generating data through encoding input data into a latent space and then decoding it back into the desired form.
#
# 3. **Transformer-based Models:** Such as GPT (Generative Pre-trained Transformer), which generate natural language text that appears human-like in its style and coherency.
#
# Generative AI has applications across multiple domains, including entertainment, healthcare, technology, and design, enabling new kinds of creativity and functionality that automate content production, enhance media experiences, and facilitate innovative solutions to complex problems.
