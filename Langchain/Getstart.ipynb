# %%
import os
from dotenv import load_dotenv
load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x000001AA2ACB4130> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001AA2ACB59C0> root_client=<openai.OpenAI object at 0x000001AA29CCEF80> root_async_client=<openai.AsyncOpenAI object at 0x000001AA2ACB4160> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********')

# %%
result=llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a subset of artificial intelligence technologies that are designed to generate new content based on input data. Unlike traditional AI systems that might only classify or predict outcomes based on provided data, generative AI creates entirely new data that reflects the patterns or characteristics of its training data. Here are a few key aspects of generative AI:\n\n1. **Types of Models**: Generative AI often uses models like Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and Transformer-based models (such as GPT for text, which stands for Generative Pre-trained Transformer).\n\n2. **Applications**: \n   - **Text Generation**: Systems like GPT can create human-like text for purposes ranging from creative writing to customer support.\n   - **Image Creation**: GANs can generate highly realistic images, which can be used in art, video game design, and even for training other AI models.\n   - **Music and Sound**: AI can compose music or generate sound effects, matching the style of particular genres or artists.\n   - **Data Augmentation**: Generative models can create additional training data for improving the robustness and performance of other machine learning models.\n\n3. **Functionality**: These systems learn from a large set of data to understand the underlying structure and patterns. Once trained, they can produce new data instances that are similar yet distinct from the original dataset.\n\n4. **Challenges**: \n   - **Quality and Authenticity**: Ensuring that generated content is high-quality and aligns with ethical guidelines.\n   - **Misuse**: Potential for misuse in creating deepfakes or misleading information.\n   - **Bias and Fairness**: The need to address biases in the training data to avoid propagating them in generated outputs.\n\nGenerative AI continues to evolve, with advancements rapidly improving the fidelity and scope of content it can create.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 383, 'prompt_tokens': 13, 'total_tokens': 396, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_eb9dce56a8', 'finish_reason': 'stop', 'logprobs': None} id='run-99b7a6e1-f81d-4c6f-baec-a067b696db16-0' usage_metadata={'input_tokens': 13, 'output_tokens': 383, 'total_tokens': 396, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='Langsmith is a tool or platform associated with LangChain, designed to enhance the development, testing, and monitoring of applications that utilize language models (LLMs). It serves as an ecosystem for developers who are building with LangChain, providing essential features to streamline their workflow. Langsmith supports the management of prompts and chains, facilitates the evaluation and testing of LLM outputs, and helps troubleshoot issues in a systematic way. Through its capabilities, Langsmith aims to make building with language models more efficient and effective, allowing developers to focus on innovation and iteration.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 111, 'prompt_tokens': 33, 'total_tokens': 144, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f9f4fb6dbf', 'finish_reason': 'stop', 'logprobs': None} id='run-5429ba3d-e670-4b8c-8164-f7350b899b56-0' usage_metadata={'input_tokens': 33, 'output_tokens': 111, 'total_tokens': 144, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a platform associated with Langchain, designed to streamline the development, testing, debugging, and monitoring of applications built with language models. It offers a toolkit and user interface that support various stages of the application lifecycle, aimed at enhancing productivity and efficiency for developers working with language models like those provided by OpenAI, Hugging Face, and others.
#
# Langsmith provides several key capabilities:
#
# 1. **Experimentation and Testing:** It allows developers to experiment with different prompts, models, and parameters to find the most effective configurations for their applications.
#
# 2. **Monitoring:** Langsmith offers features to monitor how a language model is performing in the real world, tracking metrics like response accuracy, latency, and user engagement.
#
# 3. **Debugging Tools:** If issues arise, Langsmith provides debugging tools to help identify and fix problems quickly, improving the overall reliability of applications.
#
# 4. **Scalability and Deployment:** The platform supports scaling applications efficiently and managing deployments to ensure robust performance across different environments.
#
# Overall, Langsmith is designed to simplify the often complex process of integrating and maintaining language model-based applications, allowing developers to focus on innovation and quality.
